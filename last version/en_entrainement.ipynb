# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("data_voiture_fusion.csv")

#isolation = IsolationForest()
#data["outlier"] = isolation.fit_predict(data.drop(columns = ["marque", "model","transmission","fuelType"]))
#sns.pairplot(data, hue = "outlier")
#plt.show()

# %%
#data_clean = pd.read_csv("data_voiture_clean.csv")

#isolation = IsolationForest()
#data["outlier"] = isolation.fit_predict(data.drop(columns = ["marque", "model","transmission","fuelType"]))
#sns.pairplot(data, hue = "outlier")
#plt.show()

# %%
data = data.drop(columns = ["marque", "model","transmission","fuelType"])
X = data.drop(columns = "price").values.reshape(-1, data.shape[1]-1)
y = data["price"].values.reshape(-1,1)

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X,y)

# %%
model = LinearRegression()
model.fit(Xtrain,ytrain)
model.score(Xtest,ytest)
# Out:
# 0.7030672641330427
